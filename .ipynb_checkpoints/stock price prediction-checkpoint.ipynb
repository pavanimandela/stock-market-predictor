# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as pyplot

# %%
import sys
# !{sys.executable} -m pip install yfinance
# Out:
# Collecting yfinance
#   Using cached yfinance-1.4.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: requests>=2.31 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2025.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-4.0.6-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (4.13.5)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Using cached curl_cffi-0.15.0-cp310-abi3-win_amd64.whl.metadata (18 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Using cached protobuf-7.35.0-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from curl_cffi>=0.15->yfinance) (2025.8.3)
# Collecting rich (from curl_cffi>=0.15->yfinance)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pycparser in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Collecting markdown-it-py>=2.2.0 (from rich->curl_cffi>=0.15->yfinance)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached yfinance-1.4.1-py2.py3-none-any.whl (137 kB)
# Using cached curl_cffi-0.15.0-cp310-abi3-win_amd64.whl (1.7 MB)
# Using cached multitasking-0.0.13-py3-none-any.whl (16 kB)
# Using cached peewee-4.0.6-py3-none-any.whl (146 kB)
# Using cached protobuf-7.35.0-cp310-abi3-win_amd64.whl (439 kB)
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: peewee, multitasking, websockets, protobuf, mdurl, markdown-it-py, rich, curl_cffi, yfinance
#
#    ---------------------------------------- 0/9 [peewee]
#    ---------------------------------------- 0/9 [peewee]
#    ---------------------------------------- 0/9 [peewee]
#    ---------------------------------------- 0/9 [peewee]
#    ---------------------------------------- 0/9 [peewee]
#    ---------------------------------------- 0/9 [peewee]
#    ---- ----------------------------------- 1/9 [multitasking]
#    -------- ------------------------------- 2/9 [websockets]
#    -------- ------------------------------- 2/9 [websockets]
#    -------- ------------------------------- 2/9 [websockets]
#    -------- ------------------------------- 2/9 [websockets]
#    -------- ------------------------------- 2/9 [websockets]
#    -------- ------------------------------- 2/9 [websockets]
#    -------- ------------------------------- 2/9 [websockets]
#    -------- ------------------------------- 2/9 [websockets]
#    -------- ------------------------------- 2/9 [websockets]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ------------- -------------------------- 3/9 [protobuf]
#    ----------------- ---------------------- 4/9 [mdurl]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    ---------------------- ----------------- 5/9 [markdown-it-py]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    -------------------------- ------------- 6/9 [rich]
#    ------------------------------- -------- 7/9 [curl_cffi]
#    ------------------------------- -------- 7/9 [curl_cffi]
#    ------------------------------- -------- 7/9 [curl_cffi]
#    ------------------------------- -------- 7/9 [curl_cffi]
#    ------------------------------- -------- 7/9 [curl_cffi]
#    ------------------------------- -------- 7/9 [curl_cffi]
#    ----------------------------------- ---- 8/9 [yfinance]
#    ----------------------------------- ---- 8/9 [yfinance]
#    ----------------------------------- ---- 8/9 [yfinance]
#    ----------------------------------- ---- 8/9 [yfinance]
#    ----------------------------------- ---- 8/9 [yfinance]
#    ----------------------------------- ---- 8/9 [yfinance]
#    ---------------------------------------- 9/9 [yfinance]
#
# Successfully installed curl_cffi-0.15.0 markdown-it-py-4.2.0 mdurl-0.1.2 multitasking-0.0.13 peewee-4.0.6 protobuf-7.35.0 rich-15.0.0 websockets-16.0 yfinance-1.4.1
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: C:\Users\mande\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import yfinance as yf

data = yf.download("TSLA", period="5d")
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2026-05-29  435.790009  441.070007  428.140015  439.850006  45176800
# 2026-06-01  415.880005  429.600006  415.429993  427.489990  44937900
# 2026-06-02  423.739990  424.420013  413.649994  418.220001  37596000
# 2026-06-03  423.700012  433.600006  416.000000  418.700012  44500700
# 2026-06-04         NaN         NaN         NaN         NaN  34237925

# %%
import yfinance as yf

# %%
start = "2012-01-01"
end = "2022-12-21"
stock = "GOOG"

data = yf.download(stock, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           GOOG       GOOG       GOOG       GOOG       GOOG
# Date
# 2012-01-03  16.438173  16.505863  16.116035  16.130117  147611217
# 2012-01-04  16.509071  16.557738  16.319840  16.428785  114989399
# 2012-01-05  16.280069  16.402600  16.211393  16.357146  131808205
# 2012-01-06  16.057983  16.304527  16.052300  16.283528  108119746
# 2012-01-09  15.377145  15.983378  15.346758  15.971024  233776981
# ...               ...        ...        ...        ...        ...
# 2022-12-14  94.533875  96.428325  93.175035  94.762005   26452900
# 2022-12-15  90.457344  93.264301  89.693618  92.778293   28298800
# 2022-12-16  90.120125  91.002877  89.277048  90.457353   48485500
# 2022-12-19  88.424042  90.457344  88.200875  90.139950   23020500
# 2022-12-20  88.900124  89.048904  87.323075  88.007459   21976800
#
# [2761 rows x 5 columns]

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  GOOG       GOOG       GOOG       GOOG       GOOG
# 0      2012-01-03  16.438173  16.505863  16.116035  16.130117  147611217
# 1      2012-01-04  16.509071  16.557738  16.319840  16.428785  114989399
# 2      2012-01-05  16.280069  16.402600  16.211393  16.357146  131808205
# 3      2012-01-06  16.057983  16.304527  16.052300  16.283528  108119746
# 4      2012-01-09  15.377145  15.983378  15.346758  15.971024  233776981
# ...           ...        ...        ...        ...        ...        ...
# 2756   2022-12-14  94.533875  96.428325  93.175035  94.762005   26452900
# 2757   2022-12-15  90.457344  93.264301  89.693618  92.778293   28298800
# 2758   2022-12-16  90.120125  91.002877  89.277048  90.457353   48485500
# 2759   2022-12-19  88.424042  90.457344  88.200875  90.139950   23020500
# 2760   2022-12-20  88.900124  89.048904  87.323075  88.007459   21976800
#
# [2761 rows x 6 columns]

# %%
ma_100_days = data.Close.rolling(100).mean()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.plot(ma_100_days, 'r')
plt.plot(data.Close, 'g')
plt.show()

# %%
ma_200_days = data.Close.rolling(200).mean()

# %%
plt.figure(figsize=(8,6))
plt.plot(ma_100_days, 'r')
plt.plot(ma_200_days, 'b')
plt.plot(data.Close, 'g')
plt.show()

# %%
data.dropna(inplace=True)

# %%
data_train = pd.DataFrame(data.Close[0: int(len(data)*0.80)])
data_test = pd.DataFrame(data.Close[int(len(data)*0.80): len(data)])

# %%
data_train.shape[0]
# Out:
# 2208

# %%
data_test.shape[0]
# Out:
# 553

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_train_scale = scaler.fit_transform(data_train)

# %%
x =[]
y =[]

for i in range(100, data_train_scale.shape[0]): 
    x.append(data_train_scale[i-100:i])
    y.append(data_train_scale[i,0])

# %%
x, y = np.array(x), np.array(y)

# %%
# !pip install keras tensorflow
# Out:
# Requirement already satisfied: keras in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (3.12.2)
# Requirement already satisfied: tensorflow in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from keras) (2.4.0)
# Requirement already satisfied: numpy in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from keras) (2.2.6)
# Requirement already satisfied: rich in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.19.1)
# Requirement already satisfied: ml-dtypes in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from keras) (26.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.81.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mande\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install keras tensorflow
# Out:
# Requirement already satisfied: keras in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (3.14.1)
# Requirement already satisfied: tensorflow in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from keras) (2.4.0)
# Requirement already satisfied: numpy in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from keras) (2.3.3)
# Requirement already satisfied: rich in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from keras) (0.19.1)
# Requirement already satisfied: ml-dtypes in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.81.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mande\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: C:\Users\mande\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True,
               input_shape = ((x.shape[1],1))))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation='relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu', return_sequences = True))
model.add(Dropout(0.5))

model.add(Dense(units = 1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(x , y, epochs = 50, batch_size = 32, verbose = 1)
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 24s 232ms/step - loss: 0.0764
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 247ms/step - loss: 0.0600
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 226ms/step - loss: 0.0591
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 19s 284ms/step - loss: 0.0577
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 247ms/step - loss: 0.0572
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 241ms/step - loss: 0.0570
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 21s 241ms/step - loss: 0.0568
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 233ms/step - loss: 0.0564
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 241ms/step - loss: 0.0566
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 229ms/step - loss: 0.0560
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 22s 244ms/step - loss: 0.0561
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - loss: 0.0557
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 239ms/step - loss: 0.0559
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - loss: 0.0557
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 254ms/step - loss: 0.0556
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 231ms/step - loss: 0.0554
# Epoch 17/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 271ms/step - loss: 0.0554
# Epoch 18/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 269ms/step - loss: 0.0553
# Epoch 19/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 18s 274ms/step - loss: 0.0554
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 246ms/step - loss: 0.0553
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 257ms/step - loss: 0.0552
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 234ms/step - loss: 0.0552
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 220ms/step - loss: 0.0551
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 227ms/step - loss: 0.0550
# Epoch 25/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 228ms/step - loss: 0.0551
# Epoch 26/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 239ms/step - loss: 0.0549
# Epoch 27/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 230ms/step - loss: 0.0550
# Epoch 28/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - loss: 0.0552
# Epoch 29/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 228ms/step - loss: 0.0551
# Epoch 30/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 244ms/step - loss: 0.0548
# Epoch 31/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 238ms/step - loss: 0.0548
# Epoch 32/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 234ms/step - loss: 0.0551
# Epoch 33/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 238ms/step - loss: 0.0549
# Epoch 34/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 263ms/step - loss: 0.0549
# Epoch 35/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 239ms/step - loss: 0.0547
# Epoch 36/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 262ms/step - loss: 0.0549
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 21s 298ms/step - loss: 0.0548
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 246ms/step - loss: 0.0546
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 252ms/step - loss: 0.0547
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 19s 223ms/step - loss: 0.0547
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 36s 558ms/step - loss: 0.0547
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 33s 506ms/step - loss: 0.0547
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 253ms/step - loss: 0.0547
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 17s 251ms/step - loss: 0.0546
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 242ms/step - loss: 0.0545
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 234ms/step - loss: 0.0546
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - loss: 0.0547
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 16s 237ms/step - loss: 0.0546
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 233ms/step - loss: 0.0546
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 15s 230ms/step - loss: 0.0546

# %%
pas_100_days = data_train.tail(100)

# %%
data_test = pd.concat([pas_100_days, data_test], ignore_index=True)

# %%
data_test_scale = scaler.fit_transform(data_test)

# %%
x =[]
y =[]

for i in range(100, data_test_scale.shape[0]): 
    x.append(data_test_scale[i-100:i])
    y.append(data_test_scale[i,0])
x, y = np.array(x), np.array(y)

# %%
y_predict = model.predict(x)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step

# %%
scale = 1/scaler.scale_

# %%
y = y*scale

# %%
plt.figure(figsize=(10, 8))
plt.plot(y_predict, 'r', label='Predicted Price')
plt.plot(y, 'g',  label='Original Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
model.save('stock prediction model.keras')
